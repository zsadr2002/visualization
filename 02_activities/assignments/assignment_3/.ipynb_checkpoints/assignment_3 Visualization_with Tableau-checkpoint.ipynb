# %% [markdown]
# ### The link for dataset I used for this Visualization : https://data.ontario.ca/en/dataset/ontario-top-baby-names-male/resource/9571139d-e505-4a35-82fa-192af66c5714

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('/Users/zeinabsadr/visualization/02_activities/assignments/assignment_3/Data/Dashboard.png')
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
#  > What software did you use to create your data visualization?
#
#     > Who is your intended audience?
#
# - The intended audience includes general public users interested in baby name trends
#
#     > What information or message are you trying to convey with your visualization?
#     >
# - The main message is to show the historical and recent popularity of certain boys' names. The bubble chart reveals which names have been most common since 1917 based on total counts, while the line chart focuses on recent naming trends from 2018–2023, highlighting how the frequency of these names has changed in recent years.
#
#
#     > What aspects of design did you consider when making your visualization? How did you apply them? With what elements of your plots?
#
# - Clarity and Simplicity: Only the most relevant names were visualized to avoid clutter.
# Color Coding: Distinct colors were used for each name for differentiation, especially in the line chart.
# - Chart Selection: A bubble chart was chosen for long-term popularity to represent total frequency size intuitively, while a line chart was used to show time trends in recent years.
#
#
#
#     > How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
#   - The dataset (CSV) is preserved and can be shared.
#
# - I can export the dashboard workbook (.twbx) to preserve filters, formulas, and formatting.
#
#     > How did you ensure that your data visualization is accessible?
#   - Tableau dashboards can be enhanced with alternative text and shared in accessible formats (e.g., PDF or web-embedded versions with screen-reader support).
#
#     > Who are the individuals and communities who might be impacted by your visualization?
#    -  Parents looking for name inspiration or avoiding overly common names.
#
#     > How did you choose which features of your chosen dataset to include or exclude from your visualization?
#     - I filtered the dataset to show the Top 10 most frequent boy names and selected specific years (1917–2023 for historical trends, and 2018–2023 for recent trends) to highlight both long-term popularity and recent changes.
#
#     > What ‘underwater labour’ contributed to your final data visualization product?
#   - Iterative Design: Testing different chart types and layouts to find the clearest way to communicate the story.
